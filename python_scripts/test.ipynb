# %%
import akshare as ak
stock_financial_analysis_indicator_df = ak.stock_financial_analysis_indicator(stock="300496")

# 获取最近一次主营业务收入增长率
growth_rate =  stock_financial_analysis_indicator_df['主营业务收入增长率(%)'].iloc[0]
# Out:
# 100%|██████████| 10/10 [00:12<00:00,  1.27s/it]

# %%
stock_financial_analysis_indicator_df.iloc[0].to_dict()
# Out:
# {'摊薄每股收益(元)': '0.1682',
#  '加权每股收益(元)': '0.1664',
#  '每股收益_调整后(元)': '0.1667',
#  '扣除非经常性损益后的每股收益(元)': '--',
#  '每股净资产_调整前(元)': '4.8886',
#  '每股净资产_调整后(元)': '4.7737',
#  '每股经营性现金流(元)': '0.1537',
#  '每股资本公积金(元)': '1.6232',
#  '每股未分配利润(元)': '1.8039',
#  '调整后的每股净资产(元)': '--',
#  '总资产利润率(%)': '2.0209',
#  '主营业务利润率(%)': '47.8736',
#  '总资产净利润率(%)': '2.1911',
#  '成本费用利润率(%)': '24.8952',
#  '营业利润率(%)': '17.471',
#  '主营业务成本率(%)': '51.8593',
#  '销售净利率(%)': '15.3129',
#  '股本报酬率(%)': '16.8197',
#  '净资产报酬率(%)': '3.4406',
#  '资产报酬率(%)': '2.0209',
#  '销售毛利率(%)': '--',
#  '三项费用比重': '18.2075',
#  '非主营比重': '-0.9729',
#  '主营利润比重': '273.4112',
#  '股息发放率(%)': '0.0019',
#  '投资收益率(%)': '-2.1586',
#  '主营业务利润(元)': '211659432.18',
#  '净资产收益率(%)': '3.49',
#  '加权净资产收益率(%)': '3.42',
#  '扣除非经常性损益后的净利润(元)': '49479270.57',
#  '主营业务收入增长率(%)': '32.0218',
#  '净利润增长率(%)': '36.5936',
#  '净资产增长率(%)': '21.256',
#  '总资产增长率(%)': '34.1241',
#  '应收账款周转率(次)': '0.7953',
#  '应收账款周转天数(天)': '113.1648',
#  '存货周转天数(天)': '80.4433',
# ...

# %%
help(ak.stock_financial_analysis_indicator)
# Out:
# Help on function stock_financial_analysis_indicator in module akshare.stock_fundamental.stock_finance:
#
# stock_financial_analysis_indicator(stock: str = '600004') -> pandas.core.frame.DataFrame
#     新浪财经-财务分析-财务指标
#     https://money.finance.sina.com.cn/corp/go.php/vFD_FinancialGuideLine/stockid/600004/ctrl/2019/displaytype/4.phtml
#     :param stock: 股票代码
#     :type stock: str
#     :return: 新浪财经-财务分析-财务指标
#     :rtype: pandas.DataFrame
